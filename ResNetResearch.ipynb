# %% [markdown]
# <a href="https://colab.research.google.com/github/MegaMeh/SchoolWork/blob/main/ResNetResearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip keras.zip
# Out:
# Archive:  keras.zip
#    creating: keras/
#    creating: keras/keras/
#   inflating: keras/requirements-jax-cuda.txt
#   inflating: keras/codecov.yml
#   inflating: keras/conftest.py
#   inflating: keras/pip_build.py
#   inflating: keras/LICENSE
#   inflating: keras/requirements.txt
#    creating: keras/integration_tests/
#    creating: keras/shell/
#   inflating: keras/pyproject.toml
#   inflating: keras/requirements-tensorflow-cuda.txt
#   inflating: keras/README.md
#   inflating: keras/requirements-common.txt
#   inflating: keras/setup.py
#   inflating: keras/.gitignore
#    creating: keras/guides/
#    creating: keras/examples/
#    creating: keras/benchmarks/
#   inflating: keras/requirements-torch-cuda.txt
#    creating: keras/.github/
#   inflating: keras/setup.cfg
#    creating: keras/venv/
#    creating: keras/.git/
#    creating: keras/kokoro/
#    creating: keras/.idea/
#    creating: keras/keras/activations/
#    creating: keras/keras/metrics/
# ...
